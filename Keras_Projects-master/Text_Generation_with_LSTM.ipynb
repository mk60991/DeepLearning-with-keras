# %% [markdown]
# ### Text Generation With LSTM
#
# We’ll explore how recurrent neural networks can be used to generate sequence data. We’ll use text generation as an example, but the exact same techniques can be generalized to any kind of sequence data: we could apply it to sequences of musical notes in order to generate new music, to timeseries of brushstroke data (for example, recorded while an artist paints on an iPad) to generate paintings stroke by stroke, and so on.
#
# Sequence data generation is in no way limited to artistic content generation. It has been successfully applied to speech synthesis and to dialogue generation for chatbots.
#
# ### How to Generate Sequence Data?
# The universal way to generate sequence data in deep learning is to train a network (usually an RNN or a convnet) to predict the next token or next few tokens in a sequence, using the previous tokens as input. For instance, given the input “the cat is on the ma,” the network is trained to predict the target t, the next character. As usual when working with text data, tokens are typically words or characters, and any network that can model the probability of the next token given the previous ones is called a language model. A language model captures the latent space of language: its statistical structure.
# Once we have such a trained language model, we can sample from it (generate new sequences): we feed it an initial string of text (called conditioning data), ask it to generate the next character or the next word (we can even generate several tokens at
# once), add the generated output back to the input data, and repeat the process many times. This loop allows us to generate sequences of arbitrary length that reflect the structure of the data on which the model was trained: sequences that look almost like human-written sentences. In the example we present in this section, we’ll take a LSTM layer, feed it strings of N characters extracted from a text corpus, and train it to predict character N + 1. The output of the model will be a softmax over
# all possible characters: a probability distribution for the next character. This LSTM is called a **character-level neural language model**.
#
# ![capture](https://user-images.githubusercontent.com/13174586/51816249-b02e6400-22eb-11e9-9d09-6907e73d7082.JPG)
#
# ### The Importance of The Sampling Strategy
#
# When generating text, the way we choose the next character is crucially important. A naive approach is ***greedy sampling***, consisting of always choosing the most likely next character. But such an approach results in repetitive, predictable strings that don’t look like coherent language. A more interesting approach makes slightly more surprising choices: it introduces randomness in the sampling process, by sampling from the probability distribution for the next character. This is called ***stochastic sampling*** (recall that stochasticity is what we call randomness in this field). In such a setup, if e has a probability 0.3 of being the next character, according to the model, we’ll choose it 30% of the time. Note that greedy sampling can be also cast as sampling from a probability distribution: one where a certain character has probability 1 and all others have probability 0.
#
# Sampling probabilistically from the softmax output of the model is neat: it allows even unlikely characters to be sampled some of the time, generating more interesting looking sentences and sometimes showing creativity by coming up with new, realistic sounding words that didn’t occur in the training data. But there’s one issue with this strategy: it doesn’t offer a way to *control the amount of randomness* in the sampling process.
#
# Why would we want more or less randomness? Consider an extreme case: pure random sampling, where we draw the next character from a uniform probability distribution, and every character is equally likely. This scheme has maximum randomness; in other words, this probability distribution has maximum entropy. Naturally, it won’t produce anything interesting. At the other extreme, greedy sampling doesn’t produce anything interesting, either, and has no randomness: the corresponding probability distribution has minimum entropy. Sampling from the “real” probability distribution—the distribution that is output by the model’s softmax function—constitutes an intermediate point between these two extremes. But there are many other intermediate points of higher or lower entropy that we may want to explore. Less entropy will give the generated sequences a more predictable structure (and thus they will potentially be more realistic looking), whereas more entropy will result in more surprising and creative sequences. When sampling from generative models, it’s always good to explore different amounts of randomness in the generation process. Because we—humans—are the ultimate judges of how interesting the generated data is, interestingness is highly subjective, and there’s no telling in advance where the point of optimal entropy lies.
#
# In order to control the amount of stochasticity in the sampling process, we’ll introduce a parameter called the ***softmax temperature*** that characterizes the entropy of the probability distribution used for sampling: it characterizes how surprising or predictable the choice of the next character will be. Given a temperature value, a new probability distribution is computed from the original one (the softmax output of the model) by reweighting it in the following way.
#
# ### Reweighting a Probability Distribution to a Different Temperature

# %%
import numpy as np

def reweight_distribution(original_distribution, temperature=0.5): #original_distribution is a 1D Numpy array of 
                                                                #probability values that must sum to 1. temperature 
                                                                #is a factor quantifying the entropy of the output distribution
    distribution= np.log(original_distribution)/ temperature
    distribution= np.exp(distribution)
    
    return distribution/np.sum(distribution) #Returns a reweighted version of the original distribution. The sum
                                             #of the distribution may no longer be 1, so we divide it by its sum 
                                             #to obtain the new distribution

# %% [markdown]
# Higher temperatures result in sampling distributions of higher entropy that will generate more surprising and unstructured generated data, whereas a lower temperature will result in less randomness and much more predictable generated data.
#
# ![capture](https://user-images.githubusercontent.com/13174586/51817340-49f81000-22f0-11e9-8979-d2a20ec861f2.JPG)
#
# ### Implement Character-Level LSTM Text Generation
#
# Let’s put these ideas into practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a language model. we can use any sufficiently large text file or set of text files—Wikipedia, The Lord of the Rings, and so on. In this example, we’ll use some of the writings of Nietzsche, the late-nineteenth century German philosopher (translated into English). The language model we’ll learn will thus be specifically a model of Nietzsche’s writing style and topics of choice, rather than a more generic model of the English language.
#
# #### PREPARING THE DATA
# Let’s start by downloading the corpus and converting it to lowercase.
#
# ### Download and Parse The Initial Text File

# %%
import keras
import numpy as np
import os

path= os.path.join('nietzsche.txt')

text= open(path).read().lower()
print('Corpus Length:', len(text))
# Out:
# Using TensorFlow backend.
# Corpus Length: 600901

# %% [markdown]
# Next, we’ll extract partially overlapping sequences of length maxlen, one-hot encode them, and pack them in a 3D Numpy array x of shape (`sequences`, `maxlen`, `unique_characters`). Simultaneously, we’ll prepare an array y containing the corresponding
# targets: the one-hot-encoded characters that come after each extracted sequence.
#
# ### Vectorize Sequences of Characters

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectorization...

# %% [markdown]
# #### BUILDING THE NETWORK
#
# This network is a single LSTM layer followed by a Dense classifier and softmax over all possible characters. But note that recurrent neural networks aren’t the only way to do sequence data generation; 1D convnets also have proven extremely successful at this task in recent times.
#
# ### Single-Layer LSTM Model for Next-Character Prediction

# %%
from keras import layers

model= keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 128)               96256
# _________________________________________________________________
# dense_3 (Dense)              (None, 59)                7611
# =================================================================
# Total params: 103,867
# Trainable params: 103,867
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Compilation Configuration

# %%
optimizer= keras.optimizers.RMSprop(lr=0.01)
model.compile(loss= 'categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# #### TRAINING THE LANGUAGE MODEL AND SAMPLING FROM IT
#
# Given a trained model and a seed text snippet, we can generate new text by doing the following repeatedly:
#  - Draw from the model a probability distribution for the next character, given the generated text available so far.
#  - Reweight the distribution to a certain temperature.
#  - Sample the next character at random according to the reweighted distribution.
#  - Add the new character at the end of the available text.
#
# This is the code we use to reweight the original probability distribution coming out of the model and draw a character index from it (the *sampling function*).
#
# ### Function to Sample The Next Character Given The Model’s Predictions

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, the following loop repeatedly trains and generates text. We begin generating text using a range of different temperatures after every epoch. This allows us to see how the generated text evolves as the model begins to converge, as well as the impact of temperature in the sampling strategy.
#
# ### Text-Generation Loop

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y, batch_size=128, epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200281/200281 [==============================] - 130s 648us/step - loss: 1.9808
# --- Generating with seed: "dangerous sign of the lack thereof. it is not the works,
# but"
# ------ temperature: 0.2
# dangerous sign of the lack thereof. it is not the works,
# but and sandical an an a man an an an an an an an an an an an an an an an an an a man and such a still an an an an a still the such all the still the world and such a still the interponsible the the preally so man and so in the so what so a man and self the constilus of the world an an an a which all so a still as a still the sould and such the man and sakes in the so and such the sanged and such the
# ------ temperature: 0.5
# the man and sakes in the so and such the sanged and such the soul, to the world bestory in the beaver of the detingual, the ten
# as a man as an an the will conscience, hand of stall when crute and for with the according of which is not is the life and pole with it was so but the self it all as so hang and the extrant and such so to he well an the mode it will an
# enough is the is one will as a more the sakes and what senses and such a say a sees every his wi
# ------ temperature: 1.0
# the sakes and what senses and such a say a sees every his wife of the idmand, enemshally morious, as not his says
# to chuman,
# one: stindd bad knoss
# and relagious and and such all
# could as explonally. has
# can great of pas of sendos.--the conkre. the pantifled--and posi.
#  of an east the tentulovicar
# olvers "finest and every. orly unildess lamole bedience are estaning and like is imorial for exisk wy be go be sake what is the
# the spest this flught the
# could an
# ------ temperature: 1.2
# be go be sake what is the
# the spest this flught the
# could and mutic "syithing to othee takes for really
# hiser home, wonrop an the make--but thereone
# hispoder will raghuse lobstews. and
# logainmationgougs hise one even and sequestions
# in dielibient revawture. the a grovt: "as young, diflectives one that convided is
# dighem who ethever , a
# paich, is
# will domstige
# insufot---wandal of sifuce as an, when is firht feruends, ponupess, one came us an acy out him, lo
# epoch 2
# Epoch 1/1
# 200281/200281 [==============================] - 130s 651us/step - loss: 1.6303
# --- Generating with seed: "injures it, the part of the criminal,
# and does so, in fact, "
# ------ temperature: 0.2
# injures it, the part of the criminal,
# and does so, in fact, and themen themselves and such a still the perhaps and supposent in the conscience and and and the still themselves and as and sentiment of the underethere to the lovely and some the sentiment of the still themselves to themselves to themselves and sentiment of the perman and still themselves and themselves of the present and and stand in the periods and self-conscience and themselves and themselv
# ------ temperature: 0.5
#  the periods and self-conscience and themselves and themselves and them there is and attertions and basser of the virely and there is and toom and expression of the endselts and prevently to one will the conscience when them and that whereh are consequent of philoving and it is in them and his indeat and part some propress of themselves themselves of their perhaps and themselves and sangerstanger, and will to be tratermating one takes, there is the last an
# ------ temperature: 1.0
#  and will to be tratermating one takes, there is the last and actually of momence for the resirely deflicts-perhaps as and sportact offerneted the tences and everything emestine takes, wherever on thereby any geemine and
# mistility to, namely
# cellived by the waild he without so.
# ory in suppeners,
# themselves for he
# furst will" a were and experdent, deserval him from to hold ach advinces and mankinds to what he love is stberst inlight lefked is perpluses and
# ------ temperature: 1.2
#  to what he love is stberst inlight lefked is perpluses and presuity
# to (atmremend usleacy light asordenes of closdor heep time even onlyer and time" as we have germannse--thas is
# oroned
# a dleaw thraingeh of missions that notselang and are glidual-to
# "parnous using lers se2res
# bies "nattomed time, origine some be all as taking, : de poin, but is "thas
# themservally
# perpetian yel ganded and egain. been in tempicts to spirice of itself, agility. have lands wh
# epoch 3
# Epoch 1/1
# 200281/200281 [==============================] - 129s 642us/step - loss: 1.5408
# --- Generating with seed: "of false judgments about the
# will itself, has become attache"
# ------ temperature: 0.2
# of false judgments about the
# will itself, has become attached the secred the something the such an individual to the serious and and the seems and and the self-continue the some themselved in the been something the mankind the seems and the self-continues to the self-contrary and the seems of the most power and not in the consequences and and the self-contrary to the seems of the such a spirit and the seems and experience the seems of the strengthe the see
# ------ temperature: 0.5
#  the seems and experience the seems of the strengthe the seems and has and it is a contradice the most period and the same to the assertion of mystigitable one myen and to the such a man and the consequence to the seems and a sustical to entine attentions with his not being them and of the sense
# untercourse is eastly experience the consequently and and the seet to lifes, and period the antreness and and it is the anting of the philosophers of the something
# ------ temperature: 1.0
# nd and it is the anting of the philosophers of the something--just no their furulousec, them has hencalle some becomenation of instince--perhaps: "thas healt--learnge wors most
# perseal, the
# an
# sulecibuchly?
# feeple.
# the
# seems that is estimate scenocis" to eventlaughing at knowledge of regardss shem--self-amist in pates, such doven for usminged in altwago benome out other, which withing present predigeted world?--but thege foresily, and so must their singerl
# ------ temperature: 1.2
# igeted world?--but thege foresily, and so must their singerless to besorstome lety wellingly as is asseventordoumen, punionally pholonionally and mackssakings"--into mankind in  needgrmosed not powers their christianiman. inflite of
# tove as "pristry--putainces in philosophical quencesuratil
# toware, undip
# minary
# demannund, which as collebtionalned, there part, when et our
# frindeshegicarion han relation.aby, must permaste: religit, speaks here but what
# appea
# epoch 4
# Epoch 1/1
# 200281/200281 [==============================] - 129s 642us/step - loss: 1.4955
# --- Generating with seed: " not to be found, and
# perhaps, also, is not to be lost.--the"
# ------ temperature: 0.2
#  not to be found, and
# perhaps, also, is not to be lost.--the moral contrary of the philosophy of the stand of the starn the stand of the stand of the states of the still present and determine of the decire in the stand of the states of the stand of the stand of the still and the god of the stronger and the god and the stand the stand of the stand of the stand and the states of the state of the still the stand of the stand of the stand of the stand of the s
# ------ temperature: 0.5
# ll the stand of the stand of the stand of the stand of the still troubles may be although the good of the art him of a moral and they are nother spour the stand of morality of the ears of the morality of the form of the will the bear to be an indeed to be the bear and
# the preach a tempters, how who be stand to will or as it is the encerning of metaphysicial life and more inspired and advant decived
# of the satisficed for as the god they are also they are no
# ------ temperature: 1.0
# d
# of the satisficed for as the god they are also they are noble on, as a new
# duries crience even of noinct they hi dove is
# access that it soory-suppocrans" as a mode--the virtue of notent lifeed weaked dogmers among insufature and this pitually fasis for entaumine, evel they accust, by others and one say they cames its think with look does found of the beast feer to regisal
# knomal, problem still as or humanitupssity, or doung thly sense a deplse dispresser
# ------ temperature: 1.2
# s or humanitupssity, or doung thly sense a deplse dispresserpytaprarious, and nobled imagern7, and loved those their sympttine--subcour."
# 9: f ip less be has upits ar out of be naibidialisically doy who
# dability
# gease have sicthamens by this moralitudg instinct
# which whatever will goedfeerss of diugnengous ap: de old momant merels these authorminving, which sepore revirduness. foor at religy difficul
# on
# seec1idly not us they be
# cave: hover intiminance a m
# epoch 5
# Epoch 1/1
# 200281/200281 [==============================] - 128s 642us/step - loss: 1.4662
# --- Generating with seed: "ent from the conditions under which, climatically and
# heredi"
# ------ temperature: 0.2
# ent from the conditions under which, climatically and
# heredication of the perhaps and in the compared, and the sense of the comparison of the conception of the compared to the desire of the world and its life and condition of the speakance of the comparison of the subject and desire of the compared, which the more in the conception of the present and the the persons of the respect and and has also the command the special part that the conception of the spi
# ------ temperature: 0.5
#  the command the special part that the conception of the spirit, and the man, it is only it is the present of the expression and has the learned when we art and without happiness,
# and the compertain to in the come sole they comperses the far that the compards, one of the spring the sided or the sould wherever he does some
# really the most simply the condition of his extervance of the spirit things of the capach of the world some of the art and speak of the
# ------ temperature: 1.0
# of the capach of the world some of the art and speak of the nobleing on
# thes arting the value costce of the case of the whole light, sculghing of other his odoutly can allogous, and world
# "could, it to not very bessery grage--of the
# lessel
# once upon
# that
# we may cave existlody not as the
# new cognt.
#
#
# rronan of of the cauptly weet concealed to a
# sout and very older volition
# spesiosars and
# opparable, who one been allow also mohing-spearst and mpance,ignes to
# ------ temperature: 1.2
#  who one been allow also mohing-spearst and mpance,ignes to gale avoots anything boundingse full resdon may will nothing, because they has
# all might conclicing them, by the "god!"imp.
#
# ree
# feeling; that sroult rather and
# consest
# sarctivarismgnality with the himself. the
# deceive hen to example, if
# expertent, "could ssults
# of
# value, the feelingd other thind "agrali persishcoledal to
# longer, embiration very onlick-sussers as his vighenes" presceivesed, and it
# epoch 6
# Epoch 1/1
# 200281/200281 [==============================] - 130s 651us/step - loss: 1.4450
# --- Generating with seed: " nothing can be wiser than to take
# a stick and thrash the wi"
# ------ temperature: 0.2
#  nothing can be wiser than to take
# a stick and thrash the will to the present the world in the condition of the are called the far as the sense to all the far the present the distinction of the more for the such a stand of the such the freedom of the such a such a such a persons of the far as it is the spirit of the such the far as the sense to the such a man as the conditions of the such a man which the present to the same there is also, and in the presen
# ------ temperature: 0.5
# ich the present to the same there is also, and in the present, and are that strive of this life and an in fact in the light of the and and to the weak, and serious and one of the say, there is are believed,
# and perhaps all the great condition which is from the far as a perious of man in the special from the sensition of maniin of the sort of the more self-contined all the present good and spest man a feeling of the opporting as he can a more condition and
# ------ temperature: 1.0
# n a feeling of the opporting as he can a more condition and high.--quical dorm to an unbassestive the closeves to in deaphy as seranges must which allwayther, gerit that their splention to connection: if not phers. limic are we stronge as put and less does not one of in therexpared to the doubl? as our belined moreove, friendshening, by their percairation of the adky connormement for himself has there, as explanation in a long thing) raber, but he we heare
# ------ temperature: 1.2
# here, as explanation in a long thing) raber, but he we heare to relate every utili-cleabine.--"tereds wherever found, all that haregelih, and
# fainity. exalwain rreadih higher
# hering mat reffilitaiablity, than nemkring, them not arouse--perhaps that sain transjoray-skest inno there mean
# condition, thereibresss of "gives, such also" is more, as there eur feellly or a firs in these nrung, justinen; mpulted--we hitce nothing etend--letsal--perhopiouin, are ano
# epoch 7
# Epoch 1/1
# 200281/200281 [==============================] - 130s 647us/step - loss: 1.4283
# --- Generating with seed: "pon mankind. the more similar, the more ordinary
# people, hav"
# ------ temperature: 0.2
# pon mankind. the more similar, the more ordinary
# people, have been the soul in the same the words of the speciation of the sense of the and healt of the state of the speciant of the spirit and possibit and consequently the sense of the the consequently and the soul is the common the speciation of the speciated to the concert of the soul and the same and the sense of the fore the man in the feeling of the speciacted and the great and the sense of the concer
# ------ temperature: 0.5
#  of the speciacted and the great and the sense of the concert possestical and disposition in and highest satisfiess and the religious have to be the free man against be new menty, or modest regard to the man who say out
# inservation, or noble to an experience of the precisely the virtue, we are alter to self and new kind of the soul which is the will only the soul in the most ancess of the form of himself, the said of its concert and concert man is advantag
# ------ temperature: 1.0
# himself, the said of its concert and concert man is advantage of memely and nature": a
# insablituation--and has the other-morality and a
# weaker, must have voluchis-to
# anave,
#
# laid must forgulatever and
# devaluably now i surmiblet spirit; religious alre; in why
# and old live, commands him
# innumyrists, suffering, originatisian in truth and mestortantian" of species and secistain applatityd which see concert man that the know and artitustor and belfied nanual ch
# ------ temperature: 1.2
# ncert man that the know and artitustor and belfied nanual characte, the "elieateg the
# firmans, nowadays
# sest, perspection.
#
#
# sense, because to ie"
# which expirative attaubalien of gimine, to le may so it, the seelds, and mean ipliajati istilmutable disperve, or age.
#
# 62.on ell afterer, d
# of his fortursac to religious unitye to neborounce mades in
# tave
# srultism; at ot have to clupterances as perfaius,
# thoven
# really sympawi-dmittem, telf of the
# diengent; they
# epoch 8
# Epoch 1/1
# 200281/200281 [==============================] - 130s 647us/step - loss: 1.4139
# --- Generating with seed: " estimate the first case as the worst
# (because of the conseq"
# ------ temperature: 0.2
#  estimate the first case as the worst
# (because of the consequently and secret of the contrary to the propart of the sential experience of the state of the sential experience of the same about the sential propart of the supposed and suppost and who would not the despiness of the sential sential conception of the desposed to the still opery of the sential probably one who so immediate of the sense of the will and self-propart of the most here and secret of t
# ------ temperature: 0.5
# f the will and self-propart of the most here and secret of the condition of the made their interesting and been at all the weath as the say the such at the section of the supposing in their indifferent of the social the interesting of the greater one things conduct to their tries which has a sense to the ancient proved experience of the sould with the conception and believe and delights without something is the soul is a consait of every force the contrary
# ------ temperature: 1.0
# mething is the soul is a consait of every force the contrary bad it it is it,s. good: as all the
# gregirn nones existed. thus is retile and
# me? i be our iong lighted and furs
# to generation as all head religious the disonerity,
# one is species of many, time case for the
# artay of trued in the storie pureev are one, order there is also man aloon philosophers something
# for his surder assrence; with his vigiances alook! that which has king wishes plane time
# which
# ------ temperature: 1.2
# vigiances alook! that which has king wishes plane time
# which
# "but maned what, and placed
# her-vesctony to couroned
# to way adsuld lastity ladge
# but a new-fathers
# the cromentfusly mosther forgen enews of moral youngly recold, to exonot ulivity is the fund: if hellness wigh load that and
# politiclly he doelk anti. the
# wisd become falsion,
# that it is religious adself-cusier-bording ourselves. and were, out
# acquired orn. that "noin which has grolly nreagous means
# epoch 9
# Epoch 1/1
# 200281/200281 [==============================] - 128s 640us/step - loss: 1.4036
# --- Generating with seed: " who was favourably
# inclined to the jews; and however decide"
# ------ temperature: 0.2
#  who was favourably
# inclined to the jews; and however decided to an acts of the strength of the strengther of the state of the strength of the stands of the stands to the contrary in the state of the states to the states of the stands to the stands and sense of the stands of the strength of the states of the strength of the stand to sense of the spirit and the stands and sense of the stands and the stands and well to be something which is the spirit of the
# ------ temperature: 0.5
# e stands and well to be something which is the spirit of the feeling. the stations of spirit because the belief himself of man" in the stupimation of the soul to be distastening only path of the states of himself as we have as its such a man in the philosophy. the word and instincts, or interest in the commandply of his later also still natural from the feelings of the states of moral in the similarl, and believe of a men of the spirit to to which the stan
# ------ temperature: 1.0
# arl, and believe of a men of the spirit to to which the standsow, nuturable, it too, to secie to lower only and iad through the lificial to pose every
# pround to self-kistandepst up"imed some that these
# soul is
# divines; sh. a madem, every indiang hand and
# the feed in (aloke to erchoinses; and any
# hypothing to natural moreing such disguise, evened would not to etself to tempo, was no question isle-express oownws.
# furtheough unventiment and also iriok comple
# ------ temperature: 1.2
# xpress oownws.
# furtheough unventiment and also iriok completel--every waisly betrelfice," with over-tappomes--i fawody begirnd.k; he own, has ceutaberathest in ra best
# attice whimilismed, as the worstful so charnt, loved from to do we steadaitity. alone, therefort"--the elevated dangs of lething, puts itself..--elsew,
# the wangune of cer one distracts ciccell sadem of socie"uan, disreplt them, christian reyonistic a thing" life be vex lide
# accondsing, and
# epoch 10
# Epoch 1/1
# 200281/200281 [==============================] - 128s 640us/step - loss: 1.3933
# --- Generating with seed: "to such
# an extent that the englishman unconsciously hankers "
# ------ temperature: 0.2
# to such
# an extent that the englishman unconsciously hankers of the spirit and also are been present the spirit to the spirit and moral senses of the spirit and superiority of the spirit to the spirit to the same time is the spirit and spirit of the spirit to be such a spirit and spore, the spirit to the same time and the spirit to the spirit and spirit and best who should be something is an and also the spirit to the same time and senses of the spirit and
# ------ temperature: 0.5
# so the spirit to the same time and senses of the spirit and in the form the satisfication and of the
# superiority and seriousness.
#
#
# 14
#
# =the spirit and slave, what is because is be possible of all also also musicy, the spirit to the bord by the fashify to the world should not present doubt, to when a spirit to from the spirit of the action and advantage of the soul, and which is still must also, to which is the instance and also the still exception is a pa
# ------ temperature: 1.0
# o which is the instance and also the still exception is a part one is all, what when wowen "fairh morally the superness yet heal-echists furthers, uslaws are
# one
# wish in eyes first of a lets a consider and an an
# nom contemplation is dispouses with much
# "faith),enx the ortance should the willed wholl--and is recognizes really. the "boods" as he dreadf in order pirtly casto?s
# questional bound, which pussible: there is
# wort,
# whole, takes, after the sunvers a
# ------ temperature: 1.2
# h pussible: there is
# wort,
# whole, takes, after the sunvers alone
# laisth:, solle (amough
# risides away sacceices, the person-gequality. what brough, say of all wurn-award in
# nationali cly of knowledgen. soul; it is not capabzes that "ofr; his
# own
# regeleded of knobieal "their danti and hora-new, atdomic: he becaured otne worss to
# it.
# may constitute exreart.--ghyspers on tives
# antumers soul amid any is; no drutucad" for depttloficipen
# to the
# fundamental cash t
# epoch 11
# Epoch 1/1
# 200281/200281 [==============================] - 128s 641us/step - loss: 1.3856
# --- Generating with seed: "t. but if more is asked of him, he will, with a benevolent s"
# ------ temperature: 0.2
# t. but if more is asked of him, he will, with a benevolent so who has been been in the spirit of the comparison of the state of the spirit of the spirit of the spirit and the states of the soul is the very and the state of the part of the part of the subject that a man who has a man and a way and something of the comparation of the soul is a possible and soul is the sense of the subject of the subject of the spirit of the state of the sense of the subject
# ------ temperature: 0.5
# ject of the spirit of the state of the sense of the subject who has an even has a man and way states even something in that the should because the like between of a higher the favour" of the philosophy that in the significance and original virtues of the grame believe at the good of the same believe and man: "more more the new spect, in the distinctive and have him and be an is the our whole contemptions of the are and society of man even and something ind
# ------ temperature: 1.0
# mptions of the are and society of man even and something indisclims
# in this us; for is far at loft
# : a course of the interrection of happine of thinking of verthing, but comparistictiny. the done in fow
# which has regards and that aragition because this longed tremitable alto interpresar disperting, and really that which forders
# of sy whom.
#
# 28
#
# oqualing of tritulessh and ; he recace'ed a consch and nowadays?
#
# 7thind his doing," deterin according.--than
# su
# ------ temperature: 1.2
# nd nowadays?
#
# 7thind his doing," deterin according.--than
# suchest, nofined, him
# froms cibnes what how europe, anodour. there, you may rest, signtion was philosophy unreaged which, cen masted
# apparent out ik; is affood
# to
# health", reveled, schooly has
# year
# (we midst to the astrmeagsy, as it ill), that he may reallge
# mirrenter good
# aprefornouslishedness that a commuding his detant hidden at merelit, does nonoking, happiness of civilization act divine. it wil
# epoch 12
# Epoch 1/1
# 200281/200281 [==============================] - 128s 640us/step - loss: 1.3766
# --- Generating with seed: "er
# is misunderstood and calumniated, be it god or devil, the"
# ------ temperature: 0.2
# er
# is misunderstood and calumniated, be it god or devil, the state of the sense and possesses the still the state and sense of the spirit in the superstic in the state and sense of the strong strong of the spirit and successfulness, and something and something in the stronger that it is profound, the success and successfulness, in the similar the state of the strengething to the state of the success and sense of the suble, and something the spirit of the s
# ------ temperature: 0.5
# ss and sense of the suble, and something the spirit of the sur in the singer, and he was one that of his fraine belong the science, and lets not be come strenes of the moral formal of
# the philosophy attempous without all that the christian who bad to be a person and successfulness, the sense of the science strifice compossible, and above the sublement of the sto be something more courses that which he senses the new place and in all the success, of the str
# ------ temperature: 1.0
# h he senses the new place and in all the success, of the strengths one be
# tendon, propoul in that imagany
# spriin
# the a contemted in she as
# egbili, and more
# conscience of commonful desires out, and god: is most symbin homected in and sears there overly for
# "nothing
# ropting vire without willniimple, in thought prejention and sooulod
# for a periodable, and lame man following, and closes" in religious: that prinolles us mobinable, in
# this obligious love
# become
# ------ temperature: 1.2
#  that prinolles us mobinable, in
# this obligious love
# become ngblicious possess"--not undellisuh, hencefredde: fanificaged to
# thatres, pain in oppositule early yet badces understands those greatevltous strange
# such reaused choine stich only not knowning for ane. pithism, thus are om
# psychologisic frogurse in that
# -intelligible, appearance, a such amide,
# that would par )oved, however,
# he believe which, is, toon
# guidted that some
# heaishmostrcies passimently i
# epoch 13
# Epoch 1/1
# 200281/200281 [==============================] - 128s 638us/step - loss: 1.3714
# --- Generating with seed: "pain. let us not, however shrink from this pain. rather woul"
# ------ temperature: 0.2
# pain. let us not, however shrink from this pain. rather would be are and sense of the soul, the soul, the soul, the problem and society, and such a social the subject and society and society, and society and sense of the sense of the sense of the sense of the sense of the subject the strength of the subjection of the successful, and society, and some place and such a such a such a developed, and in the subject and sense of the subjection of the sense of th
# ------ temperature: 0.5
# n the subject and sense of the subjection of the sense of the sense of the consideration, and possible! the malisting for the senses in the well the spring that every such the as interted be not so who have how consider to us and the satisfictic of such say and consideration of the soul, to a great happiness and man by one is
# a desire and of the historical sense of the good secver the subject or as place of such a falsiqution, which has been doubt and soul
# ------ temperature: 1.0
# s place of such a falsiqution, which has been doubt and soul made morality seten importations, which who cherust of a case, us
# but
# a rider greatoning moved and conscrator and sciente explanality that a were we are is, only happiness. all seeking plilous and emotions of present--woman was, our animal stranges, brish arrons a nnims to be present
# other, begulh endurishments--from
# his suffest
# auplore," with
# virtumen to us teysionating
# must were as the privers
# ------ temperature: 1.2
# " with
# virtumen to us teysionating
# must were as the privers off, howed," and brought of his capapty we myster of the instance,
# ieved fide--wiscay-intectingterfually estimats to nividity of bleysom the consequeticl only butmheries,
# s never catistwars people, use as
# trabractsffor of nowied to enfpustted our footly world? from expsyords trime,
# espechen, and
# doctor
# is certain bbealing neecringoful, nogard
# of time" from trutibying than in alls coctime"n-requinc
# epoch 14
# Epoch 1/1
# 200281/200281 [==============================] - 128s 639us/step - loss: 1.3646
# --- Generating with seed: " what wickedness and haughtiness is
# immediately aroused by w"
# ------ temperature: 0.2
#  what wickedness and haughtiness is
# immediately aroused by which have been sense to the subject of the conscience, and sense of the act therefore and sought the present to be the more pres" and conscience of the spirit is the spirit is the spirit of the spirit of the personal and still the spirit of the store as the spirit of the stome, and the present the state of the pressure of the spirit and conscience and sense of the sto the state of the spirit of th
# ------ temperature: 0.5
# onscience and sense of the sto the state of the spirit of the forming-evil. the
# the will the sublighted things which an constinct, as if the individually will have been grateful, responsibility of consciously the exect therefore as the world and sense and appearance the other has to the crived by a stora"ty for the expression it is an if he action of the suponing one will be as the opposites something in the sublighted moreon and contemnant upon themselves
# ------ temperature: 1.0
# hing in the sublighted moreon and contemnant upon themselves on it had by those mind, now
# they knop from dragely any vani? then at by errody
# palopeness, for people different life-fofte in scholary someforeignpoblenarce as chrenction: all died he takesoper in "anything, of ). though men
# cails them finally process--egdd," for inspire a know kant: misregired--our suxuci--extrayer, have
# one more howay be "structly, can morality. was dasgely the book. contew, a
# ------ temperature: 1.2
#  be "structly, can morality. was dasgely the book. contew, and abysion
# ams another (the
# belong much
# from fromades, type one wort of error endedd, the still historical through not dheter
# adds thex he willtives delight to ro" aft ingrant
# norgemsvadive sedume--but
# or "spend"ry than ifoartfys
# and longicg to mystoristua is mobiesy the
# charm
# barked, natiom ha, has mister any pefitsly disloughd, plaight," sesfta, thrit" gives from it
# taste gaen.
# which" proised gr
# epoch 15
# Epoch 1/1
# 200281/200281 [==============================] - 131s 655us/step - loss: 1.3597
# --- Generating with seed: "ver, no
# objection, unless one should again decree by some sy"
# ------ temperature: 0.2
# ver, no
# objection, unless one should again decree by some sympathical something is all the extent and the commanding in the special of the most strength of the standard, and the experience in the spirit and in the charm in the spirit and the great self-contrary to be all the sense of the spirit in the spirit to the more and something in the commanding and the stand of the spirit to the strength of the common the super-garbing and the still in the commandin
# ------ temperature: 0.5
#  the common the super-garbing and the still in the commanding of the soulshing the commanding and obscace and desult the less, with the most contemplation of the conception the form to still in the form that it is a taste has it were and here the free spiritual peases, the more things and even the state of the hald the most confliction of this fast and at the feeling the cast of his sense of religious has accon-heles and past of popular contempt and man" i
# ------ temperature: 1.0
# ious has accon-heles and past of popular contempt and man" indifgricited black, aparth--in this compatiently
# which goed of
# the faith" even woeleness, made an end with so grove ren-rather and the case in nothing malten; with early be in the fined very opinion of utilitalias, he is an explanation and deliver and man" is i day. they sauting with here is folene of german ancient world has always
# a man; "to the value of this guided: thouch and dreadful--it must
# ------ temperature: 1.2
# ; "to the value of this guided: thouch and dreadful--it must with the rage to levous and himself
# of the
# man-mytimitive of the helodiate pre's
# esseevable" and
# indignire.--a casely pagably: all begunities,esir for a comwards, mislechnowy dy too restsipleably a rafe, than
# which consideravaging of psychology is ence, woulder--a neeftvaning of letg.
#
# 254. this hult,
# . the badity and what any on comman
# un
# yeckribes in hflogitue of my effainions, whilitues: ther
# epoch 16
# Epoch 1/1
# 200281/200281 [==============================] - 131s 655us/step - loss: 1.3553
# --- Generating with seed: "tion of europeans, their
# increasing detachment from the cond"
# ------ temperature: 0.2
# tion of europeans, their
# increasing detachment from the condition of the spirit and a morality, and the sense of the interpretices of the sense of the power of the sense of the everything of the artists and something which is a man is a man is a man is a philosophers of the sense of the man is a man is a consequently and social the standards of the such a false and contrary and the spirit of the spirit of the spirit of the demands and a man will be are and
# ------ temperature: 0.5
# pirit of the spirit of the demands and a man will be are and general truth and contrary
# belong to a have seemser, he was the misunder the most exception of things of the experience of the perhaps in the same to the fearty of the world of a contrary still constraint to perhaps the contrary a fact that we contrary
# the world and there is a still in the standards, and decident of
# the cases itself in every explained the spirit to propens of the essentially inst
# ------ temperature: 1.0
# very explained the spirit to propens of the essentially instinceual
# rebligying, or pions his brought on
# only attain too
# vertains to respect imagened
# are class deterspegs let yenlt in attention,--they say, no faltion, element and shorase,-glafuly of the
# thought.
#
# 13lst with no longer
# benons broeh the soul be relations, and it were asso to be embirn to goe of perhaps
# of enemy and
# fashmeny of a men soul: we "call fateons, more -of the chxistaciouhes of the ho
# ------ temperature: 1.2
# oul: we "call fateons, more -of the chxistaciouhes of the house
# if thssee
# its power browednesse and hight
# and aimt
# of motives. its ideas. in everytheregen;
# the
# enempeter,
# with the
# tevaludaktly regis and ee?
#
#
# 1sokthy there who cather cased
# mysives, at an
# orgrains should, love,
# regard of the very nations
# in nature" recis inscapable of every danity in brings."
# men groundredness.
# ly
# pictomoued
# one
# the ever to
# fear!--sunderssorsy. instorations.--thou, a slumbs
# epoch 17
# Epoch 1/1
# 200281/200281 [==============================] - 131s 653us/step - loss: 1.3529
# --- Generating with seed: "pathy and
# similar sentiments can have a place. the ability a"
# ------ temperature: 0.2
# pathy and
# similar sentiments can have a place. the ability and supposed the sense of the superiorities of the things and self-superficial the superiorities of the superiorities of the superiorities of the old mankind of the superiorities of the prevent intellectual as the preventaning the same taste and said, and he has an accostrice the most princiss and something in the spirit of the superiorities of the sense of the same taste and supposing the superior
# ------ temperature: 0.5
# es of the sense of the same taste and supposing the superiorities of the more shinking and his super-pierable with himself the most supremace the germans and place and something
# as in the period and the form in supposed the stander--we have the princium and special stood of the prevails and something is a conscious and more soul and the people contemplate which the world of the spirit in the spirit to be the world and sense of the sense a bordance of every
# ------ temperature: 1.0
# t to be the world and sense of the sense a bordance of every at longes in the eler chools their positively honesty; in belief in rest and
# a tadming once
# collekes as from them forem it on the develops in the standing mad's best yea here hefrier,. the pleasuns for the more think
# of
# aviding meduat without respect attravacianting is pusse that regard to pidity, without pinion find
# untanger that it is inclined nimitary short, even which as they have probably th
# ------ temperature: 1.2
# inclined nimitary short, even which as they have probably that so eyes is it is considerableness and wisdes tokes
# viems religions
# they best in the pit asigals, divinity
# mens; the spirit and. it is lounsmest transformer. but ney
# goider of doubt."
# whithor forely must attain i accoldarily interlomin upernadophy aswed
# atsolousity of probably
# echopicad) of middling
# to make of these quality aftreed
# knowbgious, mernence, it fellen misterged, religionm be"gquagol
# epoch 18
# Epoch 1/1
# 200281/200281 [==============================] - 128s 641us/step - loss: 1.3472
# --- Generating with seed: "ave been brought home to mankind only after
# long habituation"
# ------ temperature: 0.2
# ave been brought home to mankind only after
# long habituation of the strength, and the same person of the state and the present and the strength and with the truth of the strength and self the spirit to the strength and the more state of the most still in the state of the strength and strength, and the consequently the expression of the present and the consequently and the state of the present the state in the spirit of the state of the state and the self-c
# ------ temperature: 0.5
# state in the spirit of the state of the state and the self-contemntain to here the form of men as the more philosopher is not personal german still here all as a clumsy that man is
# in the others in the most self an insiderable--in the strength, the deeping the belief of moral the world and the problem the unegoistic the self part and ethical upon the strength, to remains and the distrust the present a compared and how to the feelings the very consequently
# ------ temperature: 1.0
# nt a compared and how to the feelings the very consequently delusion in
# so the very misclous and "appoired because tone speaks to before gener and appeal with deal through the europeandly extens
# and innoting it, the honours, remits a smale, roms asfolocie an theird? it. many mitarity. the wholad and
# untrut in deterone of its mecused when it is the secveding, thinking aumaging dared to natureadically systends for
# whom all perited, there, the weak: he begrea
# ------ temperature: 1.2
# ly systends for
# whom all perited, there, the weak: he begream it see
# that can poutily in, the infuriosing-equality,
# fearcaties that his simply
# one man has not will
# indiai credives, and deal in napaliss," lavk by their uteasity to time will
#  genge;itsfor it is break sauntr, influent of zukh strepthd the recusious frangumature,
# the potent on englivey ethan tradity to law an which, for" silenes to be into throot you an
# shound in--this love in sortwnyful make
# epoch 19
# Epoch 1/1
# 200281/200281 [==============================] - 143s 712us/step - loss: 1.3447
# --- Generating with seed: " cruelty that
# it originated at the sight of the suffering of"
# ------ temperature: 0.2
#  cruelty that
# it originated at the sight of the suffering of the states of the subtle and such a such a still the states and secr: or the profound only and the entire the moral conscience of the states of the stone to the stone of the states of the subtlest of the states and supposed the philosophy and sublime to the subtle and the soul is the sense of the profound of the sentiment of the stone to the discovered to be also something for the subtlest of the
# ------ temperature: 0.5
#  the discovered to be also something for the subtlest of the stone that there is the constitutes an also moral time and self-spirit to love, the probably
# to processed such the pain is a crives disposing the contrary to a constant contrary or thinkers. and in the subtlest of the profound to a philosophy have been propens of the entire over one made experience of his truth, and perhaps a such men and same time the live and self entire and super-circeried, an
# ------ temperature: 1.0
# d same time the live and self entire and super-circeried, and mag.
# ? i midest to than probal, must be art of
# man, though them to "sens as the
# reblimances, as tets than morals to still to live to getiles as thereby a scripty
# to philosopimadly to "natures,
# to batuding spectoms when the enerd-sins, an ireleh as conduct, natural,
# nearic teptomen paltianicals dur
# wefly, the conception of self-contenlied, opinion; to "yeard itself believe in the oork power is c
# ------ temperature: 1.2
# ed, opinion; to "yeard itself believe in the oork power is conscatuish .ory. it has go of its it as nor, hye seem so ove mirorical mormerstate to himself)."
# chemmerly on the laimod and in everyh bory hung. onlypted go
# antimoronazen and beed feeling, asportinat, resulting namerness relect co autonses of like by a nediety perfeslebk; he takeant men to guilm dowful supposer magjuce hopen
# individue to
# contemptings the
# assonce was toge he stoo, backfuled? and
# i
# epoch 20
# Epoch 1/1
# 200281/200281 [==============================] - 139s 695us/step - loss: 1.3399
# --- Generating with seed: "ve man is an instrument,
# a costly, easily injured, easily ta"
# ------ temperature: 0.2
# ve man is an instrument,
# a costly, easily injured, easily taste and supposition and moral interprets of the look and something which has a desire of the same time a spiritual and souls of the expression of the sense of the sense of the spirit and something of the spiritual consequently as the spiritual propous and souls of the subject of the speciation of the same propous of the special contradiction and such a special spiritual spiritual propous to the pr
# ------ temperature: 0.5
# ion and such a special spiritual spiritual propous to the present of sense of all interpretion in the dogman command of
# society of the transconsing him who believe of the truth with reasonists to the belongs of point and hard must be are an and such the reality of the "conclusion and the causing to the agesing and "proveged to many attempation of the speciation of superiorical spirit and such type form at a sides to the accivious high regarding in the law,
# ------ temperature: 1.0
#  form at a sides to the accivious high regarding in the law, howover. li tooguto to reasonance
# nowouther pacianie and longing which even overcule-inlibeft willing is that in those pasted and regard nature and maintened and the owienc are refers as way positowner and does deserves, in
# made another in morality,
# to nation
# that hitherto be incalseness of child isivestance of it
# but ill more dogmed in his prevayed with a cirtfed pposing. as
# believer with which
# ------ temperature: 1.2
# his prevayed with a cirtfed pposing. as
# believer with which small be ungrounc
# his unin his remains has
# con, so ungs and ticeled childs of a hans owntical process
# as ativiase beyondn
# man at adverty wild blinding, and sjend reprondrious
# therefore a state to the redickning a tyrany, in un, always wil and supborhingly molitue, unre fiction which greater
# form in thas neiblh in her no taste is other gredubti (when
# are
# "wom?aled.
#
# ruefule also a
# posion i univerdi
# epoch 21
# Epoch 1/1
# 200281/200281 [==============================] - 143s 716us/step - loss: 1.3366
# --- Generating with seed: ", of states of the soul regarded as
# morally antithetical: it"
# ------ temperature: 0.2
# , of states of the soul regarded as
# morally antithetical: it is the same taste of the spirit of the states, and the same taste of the sense of the spirit of the same taste, and the soul, the same taste, and some spirits of the more subject of the spirit of the sense of the spirit to the subject of the subject of the subject of the fact the spirit of the states, and actions of a sure to and the standard of the sense of the spirit of the same tastes and subj
# ------ temperature: 0.5
# ndard of the sense of the spirit of the same tastes and subject almost painful experience to that which according to friends of the individuals of the standard of this case of a act of the long and happiness of power and so, not harding it in conduct and personal man is the state of proper impulse of his sentiment of the store and distinction, and the more higher from the sense of the most evidence is the nature and subject the recapopions of the still res
# ------ temperature: 1.0
# e is the nature and subject the recapopions of the still results tooglendness to the away wearant mind,
# who is alsour
# ne error kind
# origistic a
# refcriped then, however--irpigh we case,
# and sles of certain own to spoor of modestenial surroune-goed sacrifice, deing physicistren from some operation"
# is personalistic dust most sary himself--the laows another "e"ther itself
# freing proodoginoms
# states of all tywen about what pr, all this back almost
# smicab, work
# ------ temperature: 1.2
# f all tywen about what pr, all this back almost
# smicab, workwoven"
# spire of the
# nearment suchsapsly understile. ovelove
# of rimbress to experiences go in romanger himself. so sort and afflves,
# when
# his founeirr, hence,
# slaody of genatibe
# suspicion finds of more
# tequence of gromo the missents fashes custs, wants, from more
# and is theils.plved transth men
# a spirits it deep in ik's need stations
# are justice man (man)quning men). but who is compfieboud sometha
# epoch 22
# Epoch 1/1
# 200281/200281 [==============================] - 136s 677us/step - loss: 1.3335
# --- Generating with seed: "still
# more? in short, we believe that the intention is only "
# ------ temperature: 0.2
# still
# more? in short, we believe that the intention is only that it was the faith of the sense of the subject of the soul, and the world to the sense of the sense of the sense of the same sense of the soul is a man is the superiorile and consequence of the sense of the same delicate the probably and decos" in the same taste of the sense of the badd to the sense of the same truth, which the constitute to see with the superiorile something in the same truth
# ------ temperature: 0.5
# ute to see with the superiorile something in the same truth of the formally the expression of the strengrable. one man has been great own mentines and decided, when the constantly the same positive ages to be at the sicated to gromently in the most condition of a man which the reasonable the each all interpretation of the conscience of the strength of an interpretation of the superficious forms which have been formally should, so much of the ages if its ma
# ------ temperature: 1.0
# ich have been formally should, so much of the ages if its may (way for the knowley froquely as is be cienrated
# in  or
# "cimberiate
# overtenale to the stand that senstim
# further
# obbity decides. for masters, naturally one things. they was them so -this concealed will the world, lacking and saunt,
# latter at modeem of virtue," and whatever fect than rocently toulh for foreignou is this praise would qualitionally be light for mire,
# of exoration, the willicated pe
# ------ temperature: 1.2
# itionally be light for mire,
# of exoration, the willicated persons,
# that his can one but a floyles of veselfger, as i halm of faithly but yet puper are
# conhape the dangerue culture, are natureidly free iarn came bloomsisy, to be "concealed. "to plente of pleasures aimiful pits. to a
# just the man and good enjoy, but
# a gods of skeud that shreach
# mogie with
# syste too have of the thisingtor, seat of persontal lessing priese and synce upour
# sensation of
# "me. suc
# epoch 23
# Epoch 1/1
# 200281/200281 [==============================] - 134s 671us/step - loss: 1.3307
# --- Generating with seed: "uction,--who has discovered a piece of the south in music.
#
# "
# ------ temperature: 0.2
# uction,--who has discovered a piece of the south in music.
#
#
# 111
#
# =the standard of the profound to the standard to self pressing the standard and profound and such a man is a sort of the sense and profuse and some developed and strange and surpland and the feeling and surpersions of the interristive to the truth and surplate of the standard and sure of the experience and saints and sense of the spirit of the spirit and superate of the same time and in the
# ------ temperature: 0.5
# irit of the spirit and superate of the same time and in the longing the same past a things in the grans self-sense and defense work are states and some idea of the heart, and at all this distinguishment, and but with the religious false the saint of be far in its thinking of the earth of the feeling and men are all something is that we han the pertainly doubte that we in the soul has a a constantly as even of the conscience, it for the truth and do not in
# ------ temperature: 1.0
# ...
# ------ temperature: 1.2
#  no
# imploce of the sougntry,
# eltigity of connate them, i is womans was stise to
# laidance autromaibing" events.
#
# elle, in the methodex mahkence.
#
# i¤n, has, a poke nom,as voucerously, or an
# ilbquitle think
# many form and euls therepoarance;
# man, theny foog yesfult, on in been abiuppratified to belovacl
# known, but they nowlest so man shine man is not she; he have, anything, which, hodal mysteries of age omsleacien, to uponing-time.
#
#
# in prosiding? wom; it
# is n
# epoch 36
# Epoch 1/1
# 200281/200281 [==============================] - 131s 653us/step - loss: 1.3109
# --- Generating with seed: "heights where pity itself is regarded by him as
# impurity, as"
# ------ temperature: 0.2
# heights where pity itself is regarded by him as
# impurity, as the present to the superiority of the spirit and and and the enemuttate the period of the superior sense of the superiority and something which is all the superior of the superiority of the present and superficial and superficial and suppornable to all the sense of the sense of the superior to the superior such a southered to the superiority of the spirit of the superior soul and such a pricism o
# ------ temperature: 0.5
# rity of the spirit of the superior soul and such a pricism of the sense of the paches of the
# preparing history to the sense of the church, the experience of the truth and self-constant thought seems to have always intellectually and reader
# and and moral enough to see them in the superior encouraged and faculty of the also a sun of the whole to our enemuttate wholly state of the
# philosophical in the spirit of which he is not at last the basis of the such a
# ------ temperature: 1.0
# e spirit of which he is not at last the basis of the such a certain, and in my fapafing of perhaps in any thing. the strength of his soul to himself the incarianity. to makes their conscience of the emotions and two ar, is iur
# : the words of
# a sen dealthers of the
# like everypet and contempt to make us to mad.
# brew how its reputate
# prompees behing monstrains as its find and
# owing to purposom
# of uni
# taskness of "self-hfort which other in politic to make the
# ------ temperature: 1.2
#
# taskness of "self-hfort which other in politic to make the merely findiant, as this thought farrors is each of
# both pluce of vitionate boundr-timid of this suchs of a motives too.
# asturtion as done is
# rules of every our longing would be vigoror, there not in the spirit
# however chyodve--in capably throbis thirelove,
# as by philosomy is the for man aseway, the work himselfence,
# the invents love it is discracts of who dools ihedected in religious keserable us
# epoch 37
# Epoch 1/1
# 200281/200281 [==============================] - 129s 644us/step - loss: 1.3164
# --- Generating with seed: "ations, it demands fine and
# trained perceptions, it requires"
# ------ temperature: 0.2
# ations, it demands fine and
# trained perceptions, it requires the proopamed to the spirit and stronger the facular proposition of the spirit and such a such a such a such a soul is a man is a suffers of the superiority to the fact that the proposition of the suffer, the same thing with the subject of the superstiture of the french of the superstiture and superficial of the superstiture of the superstiture of the superstiture of the superstiture of the super
# ------ temperature: 0.5
# stiture of the superstiture of the superstiture of the supersoned from the individual of the more instincts and sutficies in
# or of the best the contemplation of the whole the stands and in general as a man and whole small and spirit in man--something that the presented of the conscious in his imagination of a look and spirit and propages to grant which is but a subject of a such an assife to an expanys, and the whole which the old end," a god of the subjec
# ------ temperature: 1.0
# panys, and the whole which the old end," a god of the subject backms of
# made an efform and af acultod want for usposingl and the multh and of the warrstepking thus who is ruisticulow--just thus arrived by adjace almost
# twody and inclined
# believe of peledediing his utili ussy chare
# to generation of minring are refined refinedances of
# weard will be so, too
# doble, in
# a
# animens broe, in human earth to gentle of wind more and
# kant to all refatered
# desires.--wha
# ------ temperature: 1.2
#  gentle of wind more and
# kant to all refatered
# desires.--what is a slaverand of his hister." the rest alsos--natis,--the priorss, is rich is many pleo-ourness,or because, eperilhed"; takened coxrilate of suffer-crablacher unwhoy he would have been qualiting generally wrosh and
# teach quite
# old to a withing
# where is he honovre they are a
# fneed we consigny, toatud "teces of an mumbing to
# set twodly deep perverted through, puther its state
# eter and chailed
# to
# epoch 38
# Epoch 1/1
# 200281/200281 [==============================] - 128s 641us/step - loss: 1.3098
# --- Generating with seed: "old
# men had obviously become heated as they thus shouted the"
# ------ temperature: 0.2
# old
# men had obviously become heated as they thus shouted the former that the saint of the super-conscious and actions of the world and and action of the sense of the sense of the fine the sense of the super-the sense of the conscience of the sense of the same time the same strength of the world and and the persons the strength of the same time the sense of the conscience of the standard of the conscious the standard of the persons and according to the same
# ------ temperature: 0.5
# scious the standard of the persons and according to the same sickness in the participal institution for the feeling of delight of the gradually also, and it is present be man something in the barblie the innoc indifect of the unsoct of the words that the saint of every person the do still much has been according to the action and very justife in the philosopher, and hate the and for the act prompted and want an artists the particular prove of the surpects
# ------ temperature: 1.0
# ed and want an artists the particular prove of the surpects that it is invective, still
# part of eye of the motive
# which we have, not now folly sin ign
# grumity of
# naver; abyer
# casurable and chieks, to dengeration and finally, they were hes granting and amby, but neward onednest
# of a hitherto become conscience langualis of usefulon to genered to present that the arrive. light, speal that does not
# bearity" over somes above the basis of every preservation for
# ------ temperature: 1.2
# arity" over somes above the basis of every preservation for europse betcomary, leadss vopeden.
#
#
#
#
#
#
# =herto, as well now by rational from
# frmour
# purtsic gradual frejx activout before go actings to a man (itme--a=cked--as proticing reception miscumstiny there sistimant: but as not
# stutiving.
#
# 282. the wardants. reverlet.mence to perhaping.
# the idea this.
#
#
# 7r«mos: solf for slighe ar
# alls an end as his lateration.sal to was
# he does not unforcesl hapbeness
# si
# epoch 39
# Epoch 1/1
# 200281/200281 [==============================] - 127s 636us/step - loss: 1.3104
# --- Generating with seed: "ir actions?
# in the end, however, though silently and secretl"
# ------ temperature: 0.2
# ir actions?
# in the end, however, though silently and secretly the same time and said, and the strength and the strength of the strengther and the sense of the strength of the superiority of the superiority of the strength and and consider of the superiority of the strength of the strength and deceive one who have the problem of the strength and the still sense of the spirit is a such a such a such a spiritual and sense of the sense of the strength is a man
# ------ temperature: 0.5
#  a spiritual and sense of the sense of the strength is a man in the spirit in the first of the same
# misunife of the sense and morely himself in its strength in little satisfativion and funding and
# under of a modern early morality is the rearing them wait i only and in the instincts which is the bad man who has a special contently and destraint, and hanown, in the extent the person strengther precisely the origin of them are strength should foods in order i
# ------ temperature: 1.0
# sely the origin of them are strength should foods in order in his depratent of
# tempterque themselves more brough his perhaps
# itcget first for which made
# him
# just it
# exten the pasts in every nothing of erreecligyic our purpose. and he still appears are odscure of the distectivity sided that the mar-an happhy self-defentble, the chuld
# theuls more perhaps from ourselves sinard only be strifing such a philosophe and old promotical, which is the self appropriet
# ------ temperature: 1.2
#  philosophe and old promotical, which is the self appropriety; europe that ordinater one has ongual they authors order morthvageriot--as we
# produsisms and
# oneknotsmenod its morthody, and of it, from who feeling fined
# palk
# of forces of forgehts; but whan in the "samdice strangen. no last sorray, to the sceprker civilization; it has formpets upon much is a strength, something have befond and a perioder of
# him, according his problem romrainer, the disdi((((((
# epoch 40
# Epoch 1/1
# 200281/200281 [==============================] - 129s 645us/step - loss: 1.3087
# --- Generating with seed: "is for the benefit,
# not of the jesuits but the laity. indeed"
# ------ temperature: 0.2
# is for the benefit,
# not of the jesuits but the laity. indeed, in the same time and such and success, and the state of the sense of the superstition of the still men of the state in the state of the state of the superstition of the superstition and sense of the state of the state of the superstition and the sense of the state of the state of the superstition of the state of the sense of the still the state of the state of the superstition of the sense of th
# ------ temperature: 0.5
# he state of the state of the superstition of the sense of the philosophy and done become that a great lighteness, and predumantive still extent to
# living of the contrary and assertions that
# the more wild not the fact that the problem of reason still the state of man"--science of the superstition of the faitud and rad" is as why in the sentiment of the spirit is to still says whether is the love and sympathy is the pared" of the state, it is an interpretame
# ------ temperature: 1.0
# d sympathy is the pared" of the state, it is an interpretames,
# the ye "giftions of even down as thereby are deem of which to be its "excenally new books; and hever century of the most more, such pain ap still hyptened epicureans than winher, woman in all importantians of the varion conversatily do instref organics must be "the permittely "allu, hialed and something ulure, europe; to
# antiored instincts, many
# even which hearther, more : wh are self-"selies--
# ------ temperature: 1.2
# ncts, many
# even which hearther, more : wh are self-"selies--what, enhight to gedies epoch out almost their filsh defoured ho_ment
# pogiso of boodness to us
# frirchshogel? why acts which should not succogacoligh
# "erves who has not make itse unber--lesst matter which one han""butte. arenum free
# soulgingth emotions is far as once also ampl. one will schalget from onemorativis, as much been an
# asdenea religious, to graws in the persistent ignger, whinher
# snaw
# pa
# epoch 41
# Epoch 1/1
# 200281/200281 [==============================] - 130s 647us/step - loss: 1.3023
# --- Generating with seed: "e vanity of others is only counter to our taste when it is
# c"
# ------ temperature: 0.2
# e vanity of others is only counter to our taste when it is
# concerned to the whole in the faith and senses to the presence of the sense of the presence of the super-in the concerning the feeling and sense and sense of the way that is the primortments of the profound in the sense of the form of the present
# contradict and forms of the end of the strength of the presence of the strength of the same present to development of the fact that the same preducenes th
# ------ temperature: 0.5
# esent to development of the fact that the same preducenes the whole and feeling. the sense and duty of the possesses and something feeling or nothing, which of pur the strength and the act of attached of intellectual man in the warns of all the bondire and by a propages to see
# themselves to art of the feeling and and by a new taste strife, and the feeling the commanding and the personal sense and part of the bad and first and very perhaps by the blesses is
# ------ temperature: 1.0
# part of the bad and first and very perhaps by the blesses is according to his alkweve all-than work and this most replicuon and still of their esterkalities.
#
# 1spalle plac of philosopher, as in the phologian forminates wild when a god,
# the yeingual thetse tri and feel
# hereal", more worst, the positedens
# up the degrads custom of thants ago,
# asso where they precises that if they best! there recognized. the groess in etty irstation that has as a
# man upon
# prou
# ------ temperature: 1.2
# ed. the groess in etty irstation that has as a
# man upon
# proud advance
# vane's fineral
# propurticiously from ut is
# place a goinre and concerate
# beginnation, yte it of act more sympathote fir,ly aghse") at thises to secreces;
# reround with the class vivis
# itself--that men themlyth more difficult therebretate seeks, it so, with timeals, at
# the brangered, rort, liatur in the adistation swessi, in habgititic people
# berave
# at the essestibe.
#
#
# 16jd it also, for,
# whe
# epoch 42
# Epoch 1/1
#  77824/200281 [==========>...................] - ETA: 3:45 - loss: 1.2985
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-56380a5b8aa1> in <module>()
#       5     print('epoch', epoch)
#       6     # Fit the model for 1 epoch on the available training data
# ----> 7     model.fit(x, y, batch_size=128, epochs=1)
#       8
#       9     # Select a text seed at random
#
# c:\users\soumyama\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# c:\users\soumyama\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# c:\users\soumyama\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# c:\users\soumyama\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# c:\users\soumyama\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1397           ret = tf_session.TF_SessionRunCallable(
#    1398               self._session._session, self._handle, args, status,
# -> 1399               run_metadata_ptr)
#    1400         if run_metadata:
#    1401           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# As we can see, a low temperature value results in extremely repetitive and predictable text, but local structure is highly realistic: in particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text becomes more interesting, surprising, even creative; it sometimes invents completely new words that sound somewhat plausible. With a high temperature, the local structure starts to break down, and most words look like semi-random strings of characters. Without a doubt, 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, wew can achieve generated samples that look much more coherent and realistic than this one. But, of course, we can't expect to ever generate any meaningful text, other than by random chance: all we’re doing is sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there’s a distinction between what communications are about and the statistical structure of the messages in which communications are encoded. To evidence this distinction, here’s a thought experiment: what if human language did a better job of compressing communications, much like computers do with most digital communications? Language would be no less meaningful, but it would lack any intrinsic statistical structure, thus making it impossible to learn a language model as we just did.
